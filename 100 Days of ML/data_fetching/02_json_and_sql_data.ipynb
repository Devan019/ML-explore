# %%
import pandas as pd

# %% [markdown]
# ## working with JSON

# %%
pd.read_json("demand.json")
# Out:
#           Date  Daily Metered  Non Daily Metered (NDM)  \
# 0   2021-01-01       7.816340                61.593662
# 1   2021-01-02       8.819988                64.817927
# 2   2021-01-03       8.363208                65.084971
# 3   2021-01-04      11.070071                73.712590
# 4   2021-01-05      11.696971                72.342131
# ..         ...            ...                      ...
# 815 2023-03-27      11.724638                42.022084
# 816 2023-03-28      11.615986                36.067673
# 817 2023-03-29      10.494077                31.234414
# 818 2023-03-30      11.055787                28.099440
# 819 2023-03-31      10.600473                33.663102
#
#      Large Daily Metered (LDM) non Power Gen  Power Generation  \
# 0                                   9.972410         98.520732
# 1                                  11.365715         97.945353
# 2                                  11.926284         99.608449
# ...

# %%
pd.read_json("https://storage.googleapis.com/kagglesdsdata/datasets/3508933/6130007/2023q1dailydemandjson.json?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20251016%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20251016T133701Z&X-Goog-Expires=259200&X-Goog-SignedHeaders=host&X-Goog-Signature=...")
# Out:
#           Date  Daily Metered  Non Daily Metered (NDM)  \
# 0   2021-01-01       7.816340                61.593662
# 1   2021-01-02       8.819988                64.817927
# 2   2021-01-03       8.363208                65.084971
# 3   2021-01-04      11.070071                73.712590
# 4   2021-01-05      11.696971                72.342131
# ..         ...            ...                      ...
# 815 2023-03-27      11.724638                42.022084
# 816 2023-03-28      11.615986                36.067673
# 817 2023-03-29      10.494077                31.234414
# 818 2023-03-30      11.055787                28.099440
# 819 2023-03-31      10.600473                33.663102
#
#      Large Daily Metered (LDM) non Power Gen  Power Generation  \
# 0                                   9.972410         98.520732
# 1                                  11.365715         97.945353
# 2                                  11.926284         99.608449
# ...

# %% [markdown]
# ## working with sql dataset

# %%
import mysql.connector

# %%
import mysql.connector

conn = mysql.connector.connect(
    host="localhost",
    user="root",        
    password="",
    database="world"   
)

print("✅ Connected successfully!")
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# Cell In[13], line 3
#       1 import mysql.connector
# ----> 3 conn = mysql.connector.connect(
#       4     host="localhost",
#       5     user="root",        # ✅ not 'username'
#       6     password="",
#       7     database="world"    # optional — only if you want to use a specific DB
#       8 )
#      10 print("✅ Connected successfully!")
#
# File c:\Users\devan\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\__init__.py:179, in connect(*args, **kwargs)
#     177     return CMySQLConnection(*args, **kwargs)
#     178 else:
# --> 179     return MySQLConnection(*args, **kwargs)
#
# File c:\Users\devan\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\connection.py:95, in MySQLConnection.__init__(self, *args, **kwargs)
#      92 self._pool_config_version = None
# ...

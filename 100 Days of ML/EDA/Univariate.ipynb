# %% [markdown]
# data -> numerical and cateorical types

# %%
import pandas as pd

# %%
df = pd.read_csv("../train.csv")

# %%
df.sample(5)
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 717          718         1       2   Troutt, Miss. Edwina Celia "Winnie"
# 15            16         1       2      Hewlett, Mrs. (Mary D Kingcome)
# 365          366         0       3        Adahl, Mr. Mauritz Nils Martin
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 840          841         0       3           Alhomaki, Mr. Ilmari Rudolf
#
#         Sex   Age  SibSp  Parch            Ticket    Fare Cabin Embarked
# 717  female  27.0      0      0             34218  10.500  E101        S
# 15   female  55.0      0      0            248706  16.000   NaN        S
# 365    male  30.0      0      0            C 7076   7.250   NaN        S
# 630    male  80.0      0      0             27042  30.000   A23        S
# 840    male  20.0      0      0  SOTON/O2 3101287   7.925   NaN        S

# %%
import seaborn as sb

# %% [markdown]
# 1. categorical data

# %% [markdown]
# a. countplot

# %% [markdown]
# count the frequency

# %%
sb.countplot(df['Embarked']) #work on only categorical
# Out:
# <Axes: xlabel='count', ylabel='Embarked'>

# %%
df['Survived'].value_counts().plot(kind="barh")
# Out:
# <Axes: >

# %% [markdown]
# b. piechart

# %%
df["Pclass"].value_counts().plot(kind="pie", autopct="%.2f")
# Out:
# <Axes: ylabel='Pclass'>

# %% [markdown]
# 2. Numerical Data

# %% [markdown]
# a. Histogram

# %%
import matplotlib.pyplot as plt

# %%
df["Age"].plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# b. Displot

# %%
sb.displot(df["Age"])

# %%
df["Age"].plot(kind="density") #pdf - problebility density fun
# ex age 60 - p(60) = .5%
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# c. Boxplot

# %%
sb.boxplot(df['Fare']) #use where data have outliers or not?
# Out:
# <Axes: ylabel='Fare'>

# %% [markdown]
# d. other things

# %%
df["Fare"].mean()
# Out:
# 32.204207968574636

# %%
df["Fare"].min()
# Out:
# 0.0

# %%
df["Fare"].max()
# Out:
# 512.3292

# %%
df['Fare'].skew() #+ve-skew means rigth side graph, -ve-left side, 0 => symetric
# Out:
# 4.787316519674893

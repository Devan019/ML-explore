# %%
import pickle
import numpy as np
from sklearn.tree  import DecisionTreeClassifier

with open("model.pkl", "rb") as file:
  model:DecisionTreeClassifier = pickle.load(file)

user_input = np.array([[2, "female", 10016.0, ""]], dtype=object)


(int)(model.predict(user_input)[0])
# Out:
# d:\C-drive mini\ML\.venv\lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# d:\C-drive mini\ML\.venv\lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# d:\C-drive mini\ML\.venv\lib\site-packages\sklearn\preprocessing\_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# 1

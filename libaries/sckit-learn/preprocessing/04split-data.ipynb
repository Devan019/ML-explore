# %%
import pandas as pd
data = pd.read_csv("after03.csv")
data.head(1)
# Out:
#      score  placement  city_Bangalore  city_Chennai  city_Delhi  \
# 0  0.76962        1.0             0.0           0.0         1.0
#
#    city_Hyderabad  city_Kolkata  city_Mumbai  city_Pune
# 0             0.0           0.0          0.0        0.0

# %% [markdown]
# split data - training and testing

# %%
ip = data["score"]

op = data["placement"]

ip.shape,op.shape
# Out:
# ((14,), (14,))

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(ip,op, test_size=0.25, random_state=42)

# %%
X_train
# Out:
# 5     0.525432
# 8     0.210127
# 2     0.911392
# 1     0.525432
# 13    0.359494
# 4     0.843038
# 7     1.000000
# 10    0.675949
# 3     0.318987
# 6     0.103797
# Name: score, dtype: float64

# %%
X_test
# Out:
# 9     0.587342
# 11    0.000000
# 0     0.769620
# 12    0.525432
# Name: score, dtype: float64

# %%
y_train
# Out:
# 5     1.0
# 8     0.0
# 2     1.0
# 1     0.0
# 13    0.0
# 4     1.0
# 7     1.0
# 10    0.0
# 3     0.0
# 6     0.0
# Name: placement, dtype: float64

# %%
y_test
# Out:
# 9     1.0
# 11    0.0
# 0     1.0
# 12    1.0
# Name: placement, dtype: float64

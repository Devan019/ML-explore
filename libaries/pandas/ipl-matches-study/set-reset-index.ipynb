# %%
import pandas as pd
data = pd.read_csv("matches.csv")
data.tail(1)
# Out:
#       id  season       city        date                team1  \
# 635  636    2016  Bangalore  2016-05-29  Sunrisers Hyderabad
#
#                            team2          toss_winner toss_decision  result  \
# 635  Royal Challengers Bangalore  Sunrisers Hyderabad           bat  normal
#
#      dl_applied               winner  win_by_runs  win_by_wickets  \
# 635           0  Sunrisers Hyderabad            8               0
#
#     player_of_match                  venue          umpire1       umpire2  \
# 635     BCJ Cutting  M Chinnaswamy Stadium  HDPK Dharmasena  BNJ Oxenford
#
#      umpire3
# 635      NaN

# %% [markdown]
# #### set-index for set indexing

# %% [markdown]
# ex - set id as index

# %%
data.set_index(keys="id").head(1)
# Out:
#     season       city        date                team1  \
# id
# 1     2017  Hyderabad  2017-04-05  Sunrisers Hyderabad
#
#                           team2                  toss_winner toss_decision  \
# id
# 1   Royal Challengers Bangalore  Royal Challengers Bangalore         field
#
#     result  dl_applied               winner  win_by_runs  win_by_wickets  \
# id
# 1   normal           0  Sunrisers Hyderabad           35               0
#
#    player_of_match                                      venue      umpire1  \
# id
# 1     Yuvraj Singh  Rajiv Gandhi International Stadium, Uppal  AY Dandekar
#
#      umpire2  umpire3
# id
# 1   NJ Llong      NaN

# %% [markdown]
# reset-index remove all indexes and reset indexs

# %%
data.reset_index().head(1)
# Out:
#    index  id  season       city        date                team1  \
# 0      0   1    2017  Hyderabad  2017-04-05  Sunrisers Hyderabad
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
#
#    result  dl_applied               winner  win_by_runs  win_by_wickets  \
# 0  normal           0  Sunrisers Hyderabad           35               0
#
#   player_of_match                                      venue      umpire1  \
# 0    Yuvraj Singh  Rajiv Gandhi International Stadium, Uppal  AY Dandekar
#
#     umpire2  umpire3
# 0  NJ Llong      NaN

# %% [markdown]
# reset also use for convert list to dataframe

# %%
#list - row
winners = data['winner']
winners
# Out:
# 0              Sunrisers Hyderabad
# 1           Rising Pune Supergiant
# 2            Kolkata Knight Riders
# 3                  Kings XI Punjab
# 4      Royal Challengers Bangalore
#                   ...
# 631    Royal Challengers Bangalore
# 632    Royal Challengers Bangalore
# 633            Sunrisers Hyderabad
# 634            Sunrisers Hyderabad
# 635            Sunrisers Hyderabad
# Name: winner, Length: 636, dtype: object

# %%
#dataframe
winners.reset_index()
# Out:
#      index                       winner
# 0        0          Sunrisers Hyderabad
# 1        1       Rising Pune Supergiant
# 2        2        Kolkata Knight Riders
# 3        3              Kings XI Punjab
# 4        4  Royal Challengers Bangalore
# ..     ...                          ...
# 631    631  Royal Challengers Bangalore
# 632    632  Royal Challengers Bangalore
# 633    633          Sunrisers Hyderabad
# 634    634          Sunrisers Hyderabad
# 635    635          Sunrisers Hyderabad
#
# [636 rows x 2 columns]
